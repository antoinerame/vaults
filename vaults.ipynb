# %% [markdown]
# ## P&L for the vault X between t and t+1

# %%
# Out:
# Vault address: 0xd63070114470f685b75B74D60EEc7c1113d33a3D
# Chain ID: 1 => ethereum
# Start timestamp: 1762387200, 2025-11-06
# End timestamp: 1762992000, 2025-11-13
# Start sharePriceUsd: 1.1207661516055
# End sharePriceUsd: 1.0844655263654415
# PnL: -3.2389%
